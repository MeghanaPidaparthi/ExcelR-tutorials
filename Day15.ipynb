# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghanaPidaparthi/ExcelR-tutorials/blob/main/Day15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sample()
# Out:
#      survived  pclass     sex  age  sibsp  parch  fare embarked  class    who  \
# 368         1       3  female  NaN      0      0  7.75        Q  Third  woman
#
#      adult_male deck embark_town alive  alone
# 368       False  NaN  Queenstown   yes   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
df[df.duplicated()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female   NaN      0      0   7.7500        Q   Third
# 76          0       3    male   NaN      0      0   7.8958        S   Third
# 77          0       3    male   NaN      0      0   8.0500        S   Third
# 87          0       3    male   NaN      0      0   8.0500        S   Third
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.duplicated().sum()
# Out:
# 107

# %%
df.drop_duplicates(inplace=True) #deletes the duplicate elements

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 779         0       3  female  39.0      0      5  29.1250        Q  Third
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 781         0       3  female   NaN      1      2  23.4500        S  Third
# 782         1       1    male  26.0      0      0  30.0000        C  First
# 783         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 768         1       1  female  47.0      1      1  52.5542        S  First
# 769         0       1    male  33.0      0      0   5.0000        S  First
# 774         1       1  female  56.0      0      1  83.1583        C  First
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 782         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.drop(['deck'],axis=1,inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 768         1       1  female  47.0      1      1  52.5542        S  First
# 769         0       1    male  33.0      0      0   5.0000        S  First
# 774         1       1  female  56.0      0      1  83.1583        C  First
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 782         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df['age']
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 10      4.0
# 11     58.0
#        ...
# 768    47.0
# 769    33.0
# 774    56.0
# 780    19.0
# 782    26.0
# Name: age, Length: 181, dtype: float64

# %%
df['embark_town'].unique()
# Out:
# array(['Cherbourg', 'Southampton', 'Queenstown'], dtype=object)

# %%
df['embark_town'].mode()[0]
# Out:
# 'Southampton'

# %%
df['embark_town'].fillna('Southampton')
# Out:
# 1        Cherbourg
# 3      Southampton
# 6      Southampton
# 10     Southampton
# 11     Southampton
#           ...
# 768    Southampton
# 769    Southampton
# 774      Cherbourg
# 780    Southampton
# 782      Cherbourg
# Name: embark_town, Length: 181, dtype: object

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 768         1       1  female  47.0      1      1  52.5542        S  First
# 769         0       1    male  33.0      0      0   5.0000        S  First
# 774         1       1  female  56.0      0      1  83.1583        C  First
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 782         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df['age'].median()
# Out:
# 36.0

# %%
df['age'].fillna(df['age'].median(), inplace=True)

# %%
df['age'].isnull().sum()
# Out:
# 0

# %%
df['embarked'].fillna(df['embarked'].mode()[0], inplace = True)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  181.000000  181.000000  181.000000  181.000000  181.000000  181.000000
# mean     0.674033    1.193370   35.687403    0.469613    0.480663   78.972883
# std      0.470035    0.517644   15.691057    0.645854    0.757123   76.699584
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%      1.000000    1.000000   48.000000    1.000000    1.000000   90.000000
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
df.describe(include='O' )
# Out:
#          sex embarked  who  embark_town alive
# count    181      181  181          181   181
# unique     2        3    3            3     2
# top     male        S  man  Southampton   yes
# freq      94      115   87          115   122

# %%
df['embarked'].replace({'S':1,"C":2,'Q':3})
# Out:
# 1      2
# 3      1
# 6      1
# 10     1
# 11     1
#       ..
# 768    1
# 769    1
# 774    2
# 780    1
# 782    2
# Name: embarked, Length: 181, dtype: int64

# %%
df['embarked'].unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['embared']=lb.fit_transform(df['embark_town'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'embark_town'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-0be1c383b093> in <cell line: 0>()
#       1 from sklearn.preprocessing import LabelEncoder
# ...

# %%
df
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1    0  38.0      1      0  71.2833        C      0
# 3           1       1    0  35.0      1      0  53.1000        S      0
# 6           0       1    1  54.0      0      0  51.8625        S      0
# 10          1       3    0   4.0      1      1  16.7000        S      2
# 11          1       1    0  58.0      0      0  26.5500        S      0
# ..        ...     ...  ...   ...    ...    ...      ...      ...    ...
# 768         1       1    0  47.0      1      1  52.5542        S      0
# 769         0       1    1  33.0      0      0   5.0000        S      0
# 774         1       1    0  56.0      0      1  83.1583        C      0
# 780         1       1    0  19.0      0      0  30.0000        S      0
# 782         1       1    1  26.0      0      0  30.0000        C      0
#
#        who  adult_male alive  alone  embared  embark_town_Cherbourg  \
# ...

# %%
df['sex']=lb.fit_transform(df['sex'])

# %%
df['sex'].unique()
# Out:
# array([0, 1])

# %%
df['class']=lb.fit_transform(df['class'])

# %%
df['class'].unique()
# Out:
# array([0, 2, 1])
